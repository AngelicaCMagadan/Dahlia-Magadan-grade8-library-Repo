# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelicaCMagadan/Dahlia-Magadan-grade8-library-Repo/blob/main/Dahlia_Magadan_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

url = "https://raw.githubusercontent.com/AngelicaCMagadan/Dahlia-Magadan-grade8-library-Repo/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db

path_to_key = "/content/firebase_key.json"

if firebase_admin._apps:
    firebase_admin.delete_app(firebase_admin.get_app())
    print("Existing Firebase app deleted for re-initialization.")

creds = credentials.Certificate(path_to_key)
firebase_admin.initialize_app(cred, {
    'databaseURL': "https://dahlia-magadan-library-db-default-rtdb.asia-southeast1.firebasedatabase.app"
})
print("Firebase connected successfully!")
# Out:
# Existing Firebase app deleted for re-initialization.
# Firebase connected successfully!

# %%
import requests
import json
"""
The 'books' variable is already loaded from the URL in a previous cell.
Therefore, we can directly use the 'books' variable.
"""
data = books
print("JSON file loaded")
ref = db.reference("books")
for books in data["books"]:
  ref.child(str(books["id"])).set(books)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
book_reference = db.reference("books")
book_data = book_reference.get()
print(book_data)
# Out:
# {'2001': {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, '2002': {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, '2003': {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}}

# %%
for book_id, info in book_data.items():
 print(info["title"])
# Out:
# Introduction to Python
# Data Structures Basics
# Web Development Essentials

# %%
for book_id, info in book_data.items():
    title = info["title"]
    availability = info["details"]["available"]
    print(f"{title}, Available: {availability}")
# Out:
# Introduction to Python, Available: 3
# Data Structures Basics, Available: 2
# Web Development Essentials, Available: 6

# %%
total_library_books = 0
for book_id, info in books_data.items():
    book_copies = info.get('details', {}).get('copies', 0)
    total_library_books += book_copies
print(f"Total books in library: {total_library_books}")
# Out:
# Total books in library: 15

# %%
import requests
import json

url = "https://raw.githubusercontent.com/AngelicaCMagadan/Dahlia-Magadan-grade8-library-Repo/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
import requests
import json
data = books
print("JSON file loaded")
refs = db.reference("books")
for book in data["books"]:
  refs.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!
